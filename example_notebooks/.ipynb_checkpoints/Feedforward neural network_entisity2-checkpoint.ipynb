# %%
import numpy as np
import pandas as pd

# %%
# читаем файл с лематизированным датасетом
# читаем лематизированный текст
# load dataset from file csv
f = 'C:/koltcov_python_scripts/Project_2022-23/etnohate_2023/neurol_network/final_dataset_drop_dubl.csv'
#df=pd.read_csv(f,  sep=';', encoding='utf8')
#df=pd.read_csv(f,  sep=';', encoding='cp1252' )
#df=pd.read_csv(f,  sep=';', encoding='Latin-1')
#df=pd.read_csv(f,  sep=';', encoding='ANSI')

# читаем xls файлы
df1 = pd.read_csv(f,  sep=';', encoding='utf8')


# this gives us the size of the array
print('Dataset size', df1.shape)

# here we can get size of array as two variables
num_rows1, num_feature1 = df1.shape

print('row number: ', num_rows1)
print('feature number: ', num_feature1)
print()
print('names of features: ', list(df1))
# Out:
# Dataset size (17474, 3)
# row number:  17474
# feature number:  3
#
# names of features:  ['Unnamed: 0', 'is_ethicity_superior_meaning', 'code_text']

# %%
df1
# Out:
#        Unnamed: 0 is_ethicity_superior_meaning  \
# 0               0                        irrel
# 1               1                        irrel
# 2               2                        irrel
# 3               3                        irrel
# 4               4                        irrel
# ...           ...                          ...
# 17469       17469                        irrel
# 17470       17470                        irrel
# 17471       17471                        irrel
# 17472       17472                        irrel
# 17473       17473                        irrel
#
#                                                code_text
# 0      тибетец Музыка Китая – одна из древнейших в ми...
# 1      тибетец [[id9183485|Юрий], В число 55 национал...
# 2      тибетец русофоб?! пфффф.. <br/> милок, ты слиш...
# 3      тибетец Узбекистан и Иран - унитарные, и со ст...
# 4      монгол Музыка Китая – одна из древнейших в мир...
# ...                                                  ...
# 17469  ливиец Статья интересная))но она такая же бесп...
# 17470  киприот [[id200150463|Руслан], ну жители Велик...
# 17471  саудовец Дзидек , ЖИД НЕ НАЦИОНАЛЬНОСТЬ , А МИ...
# 17472  малаец Сань, когда эти долбаные ящики передали...
# 17473  бербер RE: SgtPepper, ( А кромк Авицеены — что...
#
# [17474 rows x 3 columns]

# %%
# для удобства сделаем замену имен колонок
#df1.rename(columns = {'0':'docs'}, inplace = True )
del df1['Unnamed: 0']

# %%
# трансформируем все в колонке 'code_text' в нижний регистр
df1['code_text'] = df1['code_text'].str.lower()

# %%
df1
# Out:
#       is_ethicity_superior_meaning  \
# 0                            irrel
# 1                            irrel
# 2                            irrel
# 3                            irrel
# 4                            irrel
# ...                            ...
# 17469                        irrel
# 17470                        irrel
# 17471                        irrel
# 17472                        irrel
# 17473                        irrel
#
#                                                code_text
# 0      тибетец музыка китая – одна из древнейших в ми...
# 1      тибетец [[id9183485|юрий], в число 55 национал...
# 2      тибетец русофоб?! пфффф.. <br/> милок, ты слиш...
# 3      тибетец узбекистан и иран - унитарные, и со ст...
# 4      монгол музыка китая – одна из древнейших в мир...
# ...                                                  ...
# 17469  ливиец статья интересная))но она такая же бесп...
# 17470  киприот [[id200150463|руслан], ну жители велик...
# 17471  саудовец дзидек , жид не национальность , а ми...
# 17472  малаец сань, когда эти долбаные ящики передали...
# 17473  бербер re: sgtpepper, ( а кромк авицеены — что...
#
# [17474 rows x 2 columns]

# %%
# уберем самый большой класс
irrel_df= df1[df1["is_ethicity_superior_meaning"] == "irrel"]
high_df= df1[df1["is_ethicity_superior_meaning"] == "high"]
low_df= df1[df1["is_ethicity_superior_meaning"] == "low"]

# %%
new_data = pd.concat([high_df, low_df])
print(new_data.shape)
# Out:
# (2123, 2)

# %%
# теперь сделаем перемешивание и востановление индекса
from sklearn.utils import shuffle
shuf_data = shuffle(new_data)
print(list(shuf_data))
shuf_data.shape
# Out:
# ['is_ethicity_superior_meaning', 'code_text']
# (2123, 2)

# %%
# востоновим индексы
shuf_data.index = np.arange(len(shuf_data))

# %%
# давайте посмотрим распределение оценок
import matplotlib.pyplot as plt
# %matplotlib inline
# value_counts () - a command that allows you to calculate the number of unique values
vc = shuf_data['is_ethicity_superior_meaning'].value_counts()
vc = vc.sort_index()
print(vc)
vc.plot(kind='bar')
# Out:
# high     545
# low     1578
# Name: is_ethicity_superior_meaning, dtype: int64
# <AxesSubplot:>

# %%
df1=shuf_data

# %%
# Теперь, для того что бы подать документы и лейблы в нейронную сеть
# нужно сделать небольшой препроцессинг
# 1. нужно токенезировать
# 2. преобразовать токены в набор нулей и единиц

# %%
# проведем токенизацию с помощью keras
from keras.preprocessing.text import Tokenizer
t = Tokenizer()
t.fit_on_texts(df1['code_text'])

# %%
# кодируем документы в нули и единицы
encoded_docs = t.texts_to_matrix(df1['code_text'], mode='count')
print(encoded_docs)
# Такие документы можно подавать на вход сети
# Out:
# [[0. 4. 3. ... 0. 0. 0.]
#  [0. 6. 1. ... 0. 0. 0.]
#  [0. 2. 2. ... 0. 0. 0.]
#  ...
#  [0. 4. 2. ... 0. 0. 0.]
#  [0. 4. 5. ... 1. 1. 1.]
#  [0. 2. 4. ... 0. 0. 0.]]

# %%
# размер матрицы
print(encoded_docs.shape)
num_doc, num_words = encoded_docs.shape
# 8650 - число документов
# 64551 - число фич (число слов) - размер словаря
# Out:
# (2123, 22687)

# %%
# Разделим наш датасет на тренировочную и тестовую часть
from sklearn.model_selection import train_test_split
# делим даанные на тестовую и тренировочную коллекцию
x_train, x_valid, y_train, y_valid = train_test_split(encoded_docs, df1['is_ethicity_superior_meaning'], test_size=0.2)
print('x_train: ', x_train.shape)
print('x_valid: ', x_valid.shape)
print('------------------------------')
print('y_train: ' , y_train.shape)
print('y_valid: ' , y_valid.shape)
# Out:
# x_train:  (1698, 22687)
# x_valid:  (425, 22687)
# ------------------------------
# y_train:  (1698,)
# y_valid:  (425,)

# %%
# теперь сделаем препоцессинг лейблов
y_dummy_train = pd.get_dummies(y_train)
y_dummy_train
# Out:
#       high  low
# 51       0    1
# 1689     0    1
# 815      1    0
# 651      0    1
# 1675     1    0
# ...    ...  ...
# 136      0    1
# 536      0    1
# 706      0    1
# 1858     0    1
# 1480     0    1
#
# [1698 rows x 2 columns]

# %%
y_dummy_valid = pd.get_dummies(y_valid)
y_dummy_valid
# Out:
#       high  low
# 1867     0    1
# 56       0    1
# 2043     0    1
# 1437     0    1
# 1984     0    1
# ...    ...  ...
# 1835     1    0
# 1718     0    1
# 389      0    1
# 179      1    0
# 183      0    1
#
# [425 rows x 2 columns]

# %% [markdown]
# ### тeперь можно построить сеть прямого распространения
# создание, обучение и оценка каествасети состоит из следующих этапов
# 1. создание сети
# 2. компиляция сети
# 3. обучение сети
# 4. оценка качества

# %% [markdown]
# # простая сеть

# %%
# создание сети
from keras import models
from keras import layers

model = models.Sequential()

model.add(layers.Dense(64, activation='relu', input_shape=(22687,)))
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(64, activation='relu'))
# Dropout - дает возможно забывать сетью часть своих нейронов
model.add(layers.Dropout(0.1))
model.add(layers.Dense(2, activation='softmax'))
model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_21 (Dense)            (None, 64)                1452032
#
#  dense_22 (Dense)            (None, 64)                4160
#
#  dense_23 (Dense)            (None, 64)                4160
#
#  dropout_7 (Dropout)         (None, 64)                0
#
#  dense_24 (Dense)            (None, 2)                 130
#
# =================================================================
# Total params: 1,460,482
# Trainable params: 1,460,482
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # RNN сеть

# %%
# построение модели
from keras.models import Sequential
from keras.layers import Flatten, Dense, Embedding
from keras.layers import SimpleRNN, Reshape
from keras import layers

model = Sequential()

model.add(layers.Dense(64, activation='relu', input_shape=(22687,)))
model.add(Reshape((1, 64)))
model.add(SimpleRNN(64))
model.add(Dense(64, activation='relu'))
# Dropout - дает возможно забывать сетью часть своих нейронов
model.add(layers.Dropout(0.1))
model.add(Dense(64, activation='relu'))
model.add(Dense(2, activation='sigmoid'))
model.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_25 (Dense)            (None, 64)                1452032
#
#  reshape (Reshape)           (None, 1, 64)             0
#
#  simple_rnn (SimpleRNN)      (None, 64)                8256
#
#  dense_26 (Dense)            (None, 64)                4160
#
#  dropout_8 (Dropout)         (None, 64)                0
#
#  dense_27 (Dense)            (None, 64)                4160
#
#  dense_28 (Dense)            (None, 2)                 130
#
# =================================================================
# Total params: 1,468,738
# Trainable params: 1,468,738
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # LST сеть

# %%
# построение модели
from keras.models import Sequential
from keras.layers import Flatten, Dense, Embedding
from keras.layers import SimpleRNN, Reshape
from keras import layers
from keras.layers import LSTM

model = Sequential()

model.add(layers.Dense(64, activation='relu', input_shape=(22687,)))
model.add(Reshape((1, 64)))
model.add(LSTM(64))
model.add(Dense(64, activation='relu'))
# Dropout - дает возможно забывать сетью часть своих нейронов
model.add(layers.Dropout(0.1))
model.add(Dense(64, activation='relu'))
model.add(Dense(2, activation='sigmoid'))
model.summary()
# Out:
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_38 (Dense)            (None, 64)                1452032
#
#  reshape_4 (Reshape)         (None, 1, 64)             0
#
#  lstm_2 (LSTM)               (None, 64)                33024
#
#  dense_39 (Dense)            (None, 64)                4160
#
#  dropout_11 (Dropout)        (None, 64)                0
#
#  dense_40 (Dense)            (None, 64)                4160
#
#  dense_41 (Dense)            (None, 2)                 130
#
# =================================================================
# Total params: 1,493,506
# Trainable params: 1,493,506
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 2. компиляция сети
# теперь нужно скомпелировать нашу сеть
# optimizer='rmsprop' - алгоритм обучения сети
# loss='categorical_crossentropy'
# metrics=['accuracy'] - тип метрики качества
# loss='categorical_crossentropy' - функция потерь, которая будет минимизироваться
model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# 3. обучение сети
# запускаем процесс обучения сети
# x_train, y_train - датасет на котором обучаем сеть
# epochs=9 - число эпох обучения
# batch_size=512
# validation_data - датасет на котором производится проверка качества обученной модели
model.fit(x_train, y_dummy_train, epochs=20, batch_size=512, validation_data=(x_valid, y_dummy_valid))
# Out:
# Epoch 1/20
# 4/4 [==============================] - 2s 192ms/step - loss: 0.6624 - accuracy: 0.6184 - val_loss: 0.6039 - val_accuracy: 0.7035
# Epoch 2/20
# 4/4 [==============================] - 0s 55ms/step - loss: 0.5311 - accuracy: 0.7532 - val_loss: 0.5612 - val_accuracy: 0.7035
# Epoch 3/20
# 4/4 [==============================] - 0s 56ms/step - loss: 0.4117 - accuracy: 0.7656 - val_loss: 0.5218 - val_accuracy: 0.7647
# Epoch 4/20
# 4/4 [==============================] - 0s 53ms/step - loss: 0.3152 - accuracy: 0.8857 - val_loss: 0.5249 - val_accuracy: 0.7671
# Epoch 5/20
# 4/4 [==============================] - 0s 52ms/step - loss: 0.2401 - accuracy: 0.9099 - val_loss: 0.5686 - val_accuracy: 0.7741
# Epoch 6/20
# 4/4 [==============================] - 0s 56ms/step - loss: 0.1965 - accuracy: 0.9193 - val_loss: 0.7931 - val_accuracy: 0.7388
# Epoch 7/20
# 4/4 [==============================] - 0s 56ms/step - loss: 0.2013 - accuracy: 0.9099 - val_loss: 0.6896 - val_accuracy: 0.7624
# Epoch 8/20
# 4/4 [==============================] - 0s 51ms/step - loss: 0.1608 - accuracy: 0.9276 - val_loss: 0.6153 - val_accuracy: 0.7859
# Epoch 9/20
# 4/4 [==============================] - 0s 51ms/step - loss: 0.1686 - accuracy: 0.9134 - val_loss: 0.6942 - val_accuracy: 0.7765
# Epoch 10/20
# 4/4 [==============================] - 0s 51ms/step - loss: 0.1426 - accuracy: 0.9264 - val_loss: 0.8093 - val_accuracy: 0.7647
# Epoch 11/20
# 4/4 [==============================] - 0s 57ms/step - loss: 0.1407 - accuracy: 0.9317 - val_loss: 0.7745 - val_accuracy: 0.7694
# Epoch 12/20
# 4/4 [==============================] - 0s 52ms/step - loss: 0.1333 - accuracy: 0.9352 - val_loss: 0.8011 - val_accuracy: 0.7671
# Epoch 13/20
# 4/4 [==============================] - 0s 57ms/step - loss: 0.1172 - accuracy: 0.9488 - val_loss: 0.7789 - val_accuracy: 0.7788
# Epoch 14/20
# 4/4 [==============================] - 0s 52ms/step - loss: 0.1262 - accuracy: 0.9346 - val_loss: 0.9512 - val_accuracy: 0.7624
# Epoch 15/20
# 4/4 [==============================] - 0s 55ms/step - loss: 0.1165 - accuracy: 0.9346 - val_loss: 0.8674 - val_accuracy: 0.7694
# Epoch 16/20
# 4/4 [==============================] - 0s 55ms/step - loss: 0.1301 - accuracy: 0.9376 - val_loss: 0.9224 - val_accuracy: 0.7671
# Epoch 17/20
# 4/4 [==============================] - 0s 56ms/step - loss: 0.1115 - accuracy: 0.9399 - val_loss: 0.8015 - val_accuracy: 0.7906
# Epoch 18/20
# 4/4 [==============================] - 0s 57ms/step - loss: 0.1062 - accuracy: 0.9482 - val_loss: 0.9256 - val_accuracy: 0.7788
# Epoch 19/20
# 4/4 [==============================] - 0s 52ms/step - loss: 0.0953 - accuracy: 0.9541 - val_loss: 1.0044 - val_accuracy: 0.7765
# Epoch 20/20
# 4/4 [==============================] - 0s 54ms/step - loss: 0.1038 - accuracy: 0.9476 - val_loss: 0.9167 - val_accuracy: 0.7906

# %%
# выводим качество работы сети
results = model.evaluate(x_valid, y_dummy_valid)
# Out:
# 14/14 [==============================] - 0s 4ms/step - loss: 0.9167 - accuracy: 0.7906

# %%
print(results)
# Out:
# [0.9166838526725769, 0.7905882596969604]

# %%
# Предсказание
predictions = model.predict(x_valid)
#  число оценок и размер оценок в предсказании
print(predictions.shape)
print(predictions)
# Out:
# (425, 2)
# [[4.02709067e-01 7.70264268e-01]
#  [5.40073216e-02 9.92404342e-01]
#  [1.69615656e-01 9.71099377e-01]
#  [1.44471049e-01 9.59134400e-01]
#  [1.62903666e-02 9.98992205e-01]
#  [2.69458532e-01 8.72871757e-01]
#  [3.07932854e-01 8.52945328e-01]
#  [4.54763114e-01 7.18387425e-01]
#  [7.21522570e-01 3.06102574e-01]
#  [2.21375823e-02 9.98273492e-01]
#  [1.49329513e-01 9.49392378e-01]
#  [7.64354169e-02 9.84808564e-01]
#  [6.20678008e-01 4.04889286e-01]
#  [2.43133813e-01 9.39733446e-01]
#  [3.49261463e-02 9.96090353e-01]
#  [6.17661119e-01 4.56377119e-01]
#  [1.85390055e-01 9.26406264e-01]
#  [3.52322578e-01 7.98389435e-01]
#  [9.53724742e-01 7.20113218e-02]
#  [2.11810142e-01 9.08736289e-01]
#  [9.71937478e-02 9.80772734e-01]
#  [1.41795158e-01 9.64709520e-01]
#  [8.24689865e-04 9.99992371e-01]
#  [2.07581222e-01 9.10563886e-01]
#  [5.32930195e-01 7.54737437e-01]
#  [3.25077504e-01 8.06268454e-01]
#  [1.48365617e-01 9.60009336e-01]
#  [1.97071314e-01 9.45852578e-01]
#  [6.59928322e-01 4.15629774e-01]
#  [4.14800644e-03 9.99890208e-01]
#  [3.76778841e-03 9.99909282e-01]
#  [2.02178776e-01 9.16676164e-01]
#  [3.59640300e-01 8.16536903e-01]
#  [9.70951319e-01 4.81005311e-02]
#  [2.85500884e-02 9.97364640e-01]
#  [1.19725734e-01 9.79175508e-01]
#  [1.46904498e-01 9.50873375e-01]
#  [5.92657208e-01 4.56072539e-01]
#  [9.78027403e-01 3.86892557e-02]
#  [6.03135943e-01 4.38508183e-01]
#  [8.04483891e-03 9.99688745e-01]
#  [4.13498849e-01 7.28639007e-01]
#  [2.46328413e-02 9.97843027e-01]
#  [3.83383632e-02 9.96571064e-01]
#  [2.76096165e-02 9.97605741e-01]
#  [6.82862878e-01 3.43349278e-01]
#  [6.48964107e-01 5.14280736e-01]
#  [2.98112631e-03 9.99937534e-01]
#  [2.24721432e-03 9.99965429e-01]
#  [8.36668372e-01 2.04615623e-01]
#  [2.09280849e-02 9.98446584e-01]
#  [3.72606218e-02 9.95871544e-01]
#  [6.96462393e-03 9.99743581e-01]
#  [9.67213511e-01 5.33181131e-02]
#  [6.87408447e-03 9.99764681e-01]
#  [5.09952307e-02 9.93590713e-01]
#  [9.81578112e-01 3.23823690e-02]
#  [6.76817000e-01 4.44378376e-01]
#  [7.93813705e-01 3.48336726e-01]
#  [1.34684741e-02 9.99231994e-01]
#  [2.03064680e-01 9.27552998e-01]
#  [5.11804521e-02 9.95442152e-01]
#  [5.06769717e-02 9.93246853e-01]
#  [1.91197991e-02 9.98688340e-01]
#  [3.23784053e-02 9.96813655e-01]
#  [1.16293877e-01 9.70746160e-01]
#  [4.42632914e-01 7.58012533e-01]
#  [2.29941905e-02 9.98169422e-01]
#  [2.52587497e-02 9.97781396e-01]
#  [8.43207836e-02 9.87687290e-01]
#  [9.78903770e-02 9.76087928e-01]
#  [1.13778502e-01 9.75109100e-01]
#  [4.11246121e-02 9.96366739e-01]]

# %%
# Давайте оценим результат предсказания по классам - 2 класса
# Для этого преобразуем полученные вероятности по классам в конкретный класс
# то есть в качестве итогового класса берется класс с максимальной вероятностью
y_preds = np.argmax(predictions, axis=1).tolist()

for i in range(len(y_preds)):
    if y_preds[i]==1: y_preds[i]='low'
    if y_preds[i]==0: y_preds[i]='high'

# %%
# Давайте оценим результат предсказания по классам
# Для этого преобразуем полученные вероятности по классам в конкретный класс
# то есть в качестве итогового класса берется класс с максимальной вероятностью
#y_preds = np.argmax(predictions, axis=1).tolist()
# 2- positive
# 1- neutral
# 0- negative
#for i in range(len(y_preds)):
#    if y_preds[i]==2: y_preds[i]='low'
#    if y_preds[i]==1: y_preds[i]='irrel'
#    if y_preds[i]==0: y_preds[i]='high'

# %%
# получили предсказание в терминах классов
#y_preds

# %%
# также сделаем обратное преобразование лейблов из тестового датасета обратно в классы
yy = y_dummy_valid.idxmax(axis=1)

# %%
#yy

# %%
#  Теперь мы можем расчитать качество по каждому классу
from sklearn import metrics
from sklearn.metrics import classification_report
print(metrics.classification_report(y_preds, yy))
# Out:
#               precision    recall  f1-score   support
#
#         high       0.57      0.67      0.62       107
#          low       0.88      0.83      0.86       318
#
#     accuracy                           0.79       425
#    macro avg       0.73      0.75      0.74       425
# weighted avg       0.80      0.79      0.80       425
